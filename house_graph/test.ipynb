# %%
from house_hypergraph import House15Factory, House16Factory, House27Factory
# Out:
# d:\Python_workspace\building_maintenance_agents\.venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
from dataclasses import asdict
import json

house = House15Factory.build(house_id="15")

with open("house_15.json", "w") as f:
    json.dump(asdict(house), f, indent=2)

# %%
from nodes import FlatNode

node = FlatNode(
    section=1,
    floor=1,
    apartment_index=3,
    apartments_per_section=3,
)

node
# Out:
# FlatNode(features={'section': 1.0, 'floor': 1.0, 'apartment_index': 3.0, 'apartments_per_section': 3.0, 'x': 6.0, 'y': 6.0, 'z': 0.0})

# %%
not 1.0
# Out:
# False
