# %%
from setup import setup_modules

setup_modules()

# %%
from building_maintenance_agents.house_graph.samples import House16Factory
from building_maintenance_agents.incident_simulator import IncidentSimulator

# %%
house = House16Factory.build()

simulator = IncidentSimulator(
		house,
		base_incident_probability=0.05,
		random_seed=42,
		enable_spread=True
)
# Out:
# 2026-05-03 14:11:49.201 | INFO     | building_maintenance_agents.incident_simulator.incident_simulator:__init__:58 - IncidentSimulator initialized with 513 nodes, 1372 edges
# 2026-05-03 14:11:49.201 | INFO     | building_maintenance_agents.incident_simulator.incident_simulator:__init__:59 - Base incident probability: 0.05
# House created: 513 nodes, 1372 edges

# %% [markdown]
# Run simulation:

# %%
for step in range(3000):
		results = simulator.step()
		
		if step % 10 == 0 or results["new_incidents"] or results["resolved_incidents"]:
				print(f"\nStep {step}:")
				print(f"  Active incidents: {results['active_count']}")
				
				if results["new_incidents"]:
						print(f"  New incidents: {len(results['new_incidents'])}")
						for inc in results["new_incidents"][:3]:
								print(f"    - {inc['type']} at {inc['location']} (severity: {inc['severity']:.2f})")
				
				if results["resolved_incidents"]:
						print(f"  Resolved incidents: {len(results['resolved_incidents'])}")
# Out:
# Step 0:
#   Active incidents: 0
#
# Step 10:
#   Active incidents: 0
#
# Step 20:
#   Active incidents: 0
#
# Step 30:
#   Active incidents: 0
#
# Step 40:
#   Active incidents: 0
#
# Step 50:
#   Active incidents: 0
#
# Step 60:
#   Active incidents: 0
#
# Step 70:
#   Active incidents: 0
#
# Step 80:
#   Active incidents: 0
#
# Step 90:
#   Active incidents: 0
#
# Step 100:
#   Active incidents: 0
#
# Step 110:
#   Active incidents: 0
#
# Step 120:
#   Active incidents: 0
#
# Step 130:
#   Active incidents: 0
#
# Step 140:
#   Active incidents: 0
#
# Step 150:
#   Active incidents: 0
#
# Step 160:
#   Active incidents: 0
#
# Step 170:
#   Active incidents: 0
#
# Step 180:
#   Active incidents: 0
#
# Step 190:
#   Active incidents: 0
#
# Step 200:
#   Active incidents: 0
#
# Step 210:
#   Active incidents: 0
#
# Step 220:
#   Active incidents: 0
#
# Step 230:
#   Active incidents: 0
#
# Step 240:
#   Active incidents: 0
#
# Step 250:
#   Active incidents: 0
#
# Step 260:
#   Active incidents: 0
#
# Step 270:
#   Active incidents: 0
#
# Step 280:
#   Active incidents: 0
#
# Step 290:
#   Active incidents: 0
#
# Step 300:
#   Active incidents: 0
#
# Step 310:
#   Active incidents: 0
#
# Step 320:
#   Active incidents: 0
#
# Step 330:
#   Active incidents: 0
#
# Step 340:
#   Active incidents: 0
#
# Step 350:
#   Active incidents: 0
#
# Step 360:
#   Active incidents: 0
#
# Step 370:
#   Active incidents: 0
#
# Step 380:
#   Active incidents: 0
#
# Step 390:
#   Active incidents: 0
#
# Step 400:
#   Active incidents: 0
#
# Step 410:
#   Active incidents: 0
#
# Step 420:
#   Active incidents: 0
#
# Step 430:
#   Active incidents: 0
#
# Step 440:
#   Active incidents: 0
#
# Step 450:
#   Active incidents: 0
#
# Step 460:
#   Active incidents: 0
#
# Step 470:
#   Active incidents: 0
#
# Step 480:
#   Active incidents: 0
#
# Step 490:
#   Active incidents: 0
#
# Step 500:
#   Active incidents: 0
#
# Step 510:
#   Active incidents: 0
#
# Step 520:
#   Active incidents: 0
#
# Step 530:
#   Active incidents: 0
#
# Step 540:
#   Active incidents: 0
#
# Step 550:
#   Active incidents: 0
#
# Step 560:
#   Active incidents: 0
#
# Step 570:
#   Active incidents: 0
#
# Step 580:
#   Active incidents: 0
#
# Step 590:
#   Active incidents: 0
#
# Step 600:
#   Active incidents: 0
#
# Step 610:
#   Active incidents: 0
#
# Step 620:
#   Active incidents: 0
#
# Step 630:
#   Active incidents: 0
#
# Step 640:
#   Active incidents: 0
#
# Step 650:
#   Active incidents: 0
#
# Step 660:
#   Active incidents: 0
#
# Step 670:
#   Active incidents: 0
#
# Step 680:
#   Active incidents: 0
#
# Step 690:
#   Active incidents: 0
#
# Step 700:
#   Active incidents: 0
#
# Step 710:
#   Active incidents: 0
#
# Step 720:
#   Active incidents: 0
#
# Step 730:
#   Active incidents: 0
#
# Step 740:
#   Active incidents: 0
#
# Step 750:
#   Active incidents: 0
#
# Step 760:
#   Active incidents: 0
#
# Step 770:
#   Active incidents: 0
#
# Step 780:
#   Active incidents: 0
#
# Step 790:
#   Active incidents: 0
#
# Step 800:
#   Active incidents: 0
#
# Step 810:
#   Active incidents: 0
#
# Step 820:
#   Active incidents: 0
#
# Step 830:
#   Active incidents: 0
#
# Step 840:
#   Active incidents: 0
#
# Step 850:
#   Active incidents: 0
#
# Step 860:
#   Active incidents: 0
#
# Step 870:
#   Active incidents: 0
#
# Step 880:
#   Active incidents: 0
#
# Step 890:
#   Active incidents: 0
#
# Step 900:
#   Active incidents: 0
#
# Step 910:
#   Active incidents: 0
#
# Step 920:
#   Active incidents: 0
#
# Step 930:
#   Active incidents: 0
#
# Step 940:
#   Active incidents: 0
#
# Step 950:
#   Active incidents: 0
#
# Step 960:
#   Active incidents: 0
#
# Step 970:
#   Active incidents: 0
#
# Step 980:
#   Active incidents: 0
#
# Step 990:
#   Active incidents: 0
#
# Step 1000:
#   Active incidents: 0
#
# Step 1010:
#   Active incidents: 0
#
# Step 1020:
#   Active incidents: 0
#
# Step 1030:
#   Active incidents: 0
#
# Step 1040:
#   Active incidents: 0
#
# Step 1050:
#   Active incidents: 0
#
# Step 1060:
#   Active incidents: 0
#
# Step 1070:
#   Active incidents: 0
#
# Step 1080:
#   Active incidents: 0
#
# Step 1090:
#   Active incidents: 0
#
# Step 1100:
#   Active incidents: 0
#
# Step 1110:
#   Active incidents: 0
#
# Step 1120:
#   Active incidents: 0
#
# Step 1130:
#   Active incidents: 0
#
# Step 1140:
#   Active incidents: 0
#
# Step 1150:
#   Active incidents: 0
#
# Step 1160:
#   Active incidents: 0
#
# Step 1170:
#   Active incidents: 0
#
# Step 1180:
#   Active incidents: 0
#
# Step 1190:
#   Active incidents: 0
#
# Step 1200:
#   Active incidents: 0
#
# Step 1210:
#   Active incidents: 0
#
# Step 1220:
#   Active incidents: 0
#
# Step 1230:
#   Active incidents: 0
#
# Step 1240:
#   Active incidents: 0
#
# Step 1250:
#   Active incidents: 0
#
# Step 1260:
#   Active incidents: 0
#
# Step 1270:
#   Active incidents: 0
#
# Step 1280:
#   Active incidents: 0
#
# Step 1290:
#   Active incidents: 0
#
# Step 1300:
#   Active incidents: 0
#
# Step 1310:
#   Active incidents: 0
#
# Step 1320:
#   Active incidents: 0
#
# Step 1330:
#   Active incidents: 0
#
# Step 1340:
#   Active incidents: 0
#
# Step 1350:
#   Active incidents: 0
#
# Step 1360:
#   Active incidents: 0
#
# Step 1370:
#   Active incidents: 0
#
# Step 1380:
#   Active incidents: 0
#
# Step 1390:
#   Active incidents: 0
#
# Step 1400:
#   Active incidents: 0
#
# Step 1410:
#   Active incidents: 0
#
# Step 1420:
#   Active incidents: 0
#
# Step 1430:
#   Active incidents: 0
#
# Step 1440:
#   Active incidents: 0
#
# Step 1450:
#   Active incidents: 0
#
# Step 1460:
#   Active incidents: 0
#
# Step 1470:
#   Active incidents: 0
#
# Step 1480:
#   Active incidents: 0
#
# Step 1490:
#   Active incidents: 0
#
# Step 1500:
#   Active incidents: 0
#
# Step 1510:
#   Active incidents: 0
#
# Step 1520:
#   Active incidents: 0
#
# Step 1530:
#   Active incidents: 0
#
# Step 1540:
#   Active incidents: 0
#
# Step 1550:
#   Active incidents: 0
#
# Step 1560:
#   Active incidents: 0
#
# Step 1570:
#   Active incidents: 0
#
# Step 1580:
#   Active incidents: 0
#
# Step 1590:
#   Active incidents: 0
#
# Step 1600:
#   Active incidents: 0
#
# Step 1610:
#   Active incidents: 0
#
# Step 1620:
#   Active incidents: 0
#
# Step 1630:
#   Active incidents: 0
#
# Step 1640:
#   Active incidents: 0
#
# Step 1650:
#   Active incidents: 0
#
# Step 1660:
#   Active incidents: 0
#
# Step 1670:
#   Active incidents: 0
#
# Step 1680:
#   Active incidents: 0
#
# Step 1690:
#   Active incidents: 0
#
# Step 1700:
#   Active incidents: 0
#
# Step 1710:
#   Active incidents: 0
#
# Step 1720:
#   Active incidents: 0
#
# Step 1730:
#   Active incidents: 0
#
# Step 1740:
#   Active incidents: 0
#
# Step 1750:
#   Active incidents: 0
#
# Step 1760:
#   Active incidents: 0
# 2026-05-03 14:11:50.186 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure started with severity 0.60
# 2026-05-03 14:11:50.187 | DEBUG    | building_maintenance_agents.incident_simulator.incident_simulator:_create_incident:201 - New incident: gvs_riser_failure at node 6085778240, severity=0.60
# 2026-05-03 14:11:50.188 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure spread from 6085778240
# 2026-05-03 14:11:50.188 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure spread from 6085778240
# 2026-05-03 14:11:50.189 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.57
# 2026-05-03 14:11:50.189 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.33
# 2026-05-03 14:11:50.189 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.33
# 2026-05-03 14:11:50.191 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.54
# 2026-05-03 14:11:50.191 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.30
# 2026-05-03 14:11:50.192 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.30
# 2026-05-03 14:11:50.193 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.51
# 2026-05-03 14:11:50.193 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.27
# 2026-05-03 14:11:50.193 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.27
# 2026-05-03 14:11:50.195 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.48
# 2026-05-03 14:11:50.195 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.24
# 2026-05-03 14:11:50.195 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.24
# 2026-05-03 14:11:50.196 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.45
# 2026-05-03 14:11:50.197 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.21
# 2026-05-03 14:11:50.197 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.21
# 2026-05-03 14:11:50.198 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.42
# 2026-05-03 14:11:50.198 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.18
# 2026-05-03 14:11:50.199 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.18
# 2026-05-03 14:11:50.200 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.39
# 2026-05-03 14:11:50.200 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.15
# 2026-05-03 14:11:50.200 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.15
# 2026-05-03 14:11:50.201 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.36
# 2026-05-03 14:11:50.202 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.12
# 2026-05-03 14:11:50.202 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.12
# 2026-05-03 14:11:50.203 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.33
# 2026-05-03 14:11:50.204 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.09
# 2026-05-03 14:11:50.204 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.09
# 2026-05-03 14:11:50.205 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.30
# 2026-05-03 14:11:50.206 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.06
# 2026-05-03 14:11:50.206 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.06
# 2026-05-03 14:11:50.208 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.27
# 2026-05-03 14:11:50.208 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.03
# 2026-05-03 14:11:50.208 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.03
# 2026-05-03 14:11:50.210 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.24
# 2026-05-03 14:11:50.210 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.210 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.211 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.21
# 2026-05-03 14:11:50.212 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.212 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.217 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.18
# Step 1770:
#   Active incidents: 0
#
# Step 1780:
#   Active incidents: 0
#
# Step 1790:
#   Active incidents: 0
#
# Step 1800:
#   Active incidents: 0
#
# Step 1808:
#   Active incidents: 0
#   New incidents: 1
#     - gvs_riser_failure at 6085778240 (severity: 0.60)
#
# Step 1810:
#   Active incidents: 3
#
# Step 1820:
#   Active incidents: 3
# 2026-05-03 14:11:50.223 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.223 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.225 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.15
# 2026-05-03 14:11:50.225 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.225 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.227 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.12
# 2026-05-03 14:11:50.227 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.227 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.228 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.09
# 2026-05-03 14:11:50.229 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.229 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.230 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.06
# 2026-05-03 14:11:50.231 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.231 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.232 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.03
# 2026-05-03 14:11:50.232 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.233 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.234 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.234 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.234 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.235 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.236 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.236 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.237 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.237 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.238 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.239 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.239 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.239 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.240 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.240 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# 2026-05-03 14:11:50.241 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# 2026-05-03 14:11:50.242 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.243 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.244 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.245 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# Step 1830:
#   Active incidents: 3
#
# Step 1832:
#   Active incidents: 3
#   Resolved incidents: 2
#
# Step 1836:
#   Active incidents: 1
#   Resolved incidents: 1
#
# Step 1840:
#   Active incidents: 0
#
# Step 1850:
#   Active incidents: 0
#
# Step 1860:
#   Active incidents: 0
#
# Step 1870:
#   Active incidents: 0
#
# Step 1880:
#   Active incidents: 0
#
# Step 1890:
#   Active incidents: 0
#
# Step 1900:
#   Active incidents: 0
#
# Step 1910:
#   Active incidents: 0
#
# Step 1920:
#   Active incidents: 0
#
# Step 1930:
#   Active incidents: 0
#
# Step 1940:
#   Active incidents: 0
#
# Step 1950:
#   Active incidents: 0
#
# Step 1960:
#   Active incidents: 0
#
# Step 1970:
#   Active incidents: 0
#
# Step 1980:
#   Active incidents: 0
#
# Step 1990:
#   Active incidents: 0
#
# Step 2000:
#   Active incidents: 0
#
# Step 2010:
#   Active incidents: 0
#
# Step 2020:
#   Active incidents: 0
#
# Step 2030:
#   Active incidents: 0
#
# Step 2040:
#   Active incidents: 0
#
# Step 2050:
#   Active incidents: 0
#
# Step 2060:
#   Active incidents: 0
#
# Step 2070:
#   Active incidents: 0
#
# Step 2080:
#   Active incidents: 0
#
# Step 2090:
#   Active incidents: 0
#
# Step 2100:
#   Active incidents: 0
#
# Step 2110:
#   Active incidents: 0
#
# Step 2120:
#   Active incidents: 0
#
# Step 2130:
#   Active incidents: 0
#
# Step 2140:
#   Active incidents: 0
#
# Step 2150:
#   Active incidents: 0
#
# Step 2160:
#   Active incidents: 0
#
# Step 2170:
#   Active incidents: 0
# 2026-05-03 14:11:50.628 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure started with severity 0.47
# 2026-05-03 14:11:50.628 | DEBUG    | building_maintenance_agents.incident_simulator.incident_simulator:_create_incident:201 - New incident: gvs_riser_failure at node 10975585200, severity=0.47
# 2026-05-03 14:11:50.629 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure spread from 10975585200
# 2026-05-03 14:11:50.629 | INFO     | building_maintenance_agents.house_graph.states.incident_state:set_incident:17 - Set incident: gvs_riser_failure spread from 10975585200
# 2026-05-03 14:11:50.630 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.44
# 2026-05-03 14:11:50.630 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.25
# 2026-05-03 14:11:50.630 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.25
# 2026-05-03 14:11:50.631 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.41
# 2026-05-03 14:11:50.632 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.22
# 2026-05-03 14:11:50.632 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.22
# 2026-05-03 14:11:50.633 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.38
# Step 2180:
#   Active incidents: 0
#
# Step 2190:
#   Active incidents: 0
#
# Step 2200:
#   Active incidents: 0
#
# Step 2210:
#   Active incidents: 0
#
# Step 2220:
#   Active incidents: 0
#
# Step 2230:
#   Active incidents: 0
#
# Step 2240:
#   Active incidents: 0
#
# Step 2250:
#   Active incidents: 0
#
# Step 2260:
#   Active incidents: 0
#
# Step 2270:
#   Active incidents: 0
#
# Step 2280:
#   Active incidents: 0
#
# Step 2290:
#   Active incidents: 0
#
# Step 2300:
#   Active incidents: 0
#
# Step 2310:
#   Active incidents: 0
#
# Step 2320:
#   Active incidents: 0
#
# Step 2330:
#   Active incidents: 0
#
# Step 2340:
#   Active incidents: 0
#
# Step 2350:
#   Active incidents: 0
#
# Step 2360:
#   Active incidents: 0
#
# Step 2370:
#   Active incidents: 0
#
# Step 2380:
#   Active incidents: 0
#
# Step 2390:
#   Active incidents: 0
#
# Step 2400:
#   Active incidents: 0
#
# Step 2410:
#   Active incidents: 0
#
# Step 2420:
#   Active incidents: 0
#
# Step 2430:
#   Active incidents: 0
#
# Step 2440:
#   Active incidents: 0
#
# Step 2450:
#   Active incidents: 0
#
# Step 2460:
#   Active incidents: 0
#
# Step 2470:
#   Active incidents: 0
#
# Step 2480:
#   Active incidents: 0
#
# Step 2490:
#   Active incidents: 0
#
# Step 2500:
#   Active incidents: 0
#
# Step 2510:
#   Active incidents: 0
#
# Step 2514:
#   Active incidents: 0
#   New incidents: 1
#     - gvs_riser_failure at 10975585200 (severity: 0.47)
# 2026-05-03 14:11:50.633 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.19
# 2026-05-03 14:11:50.634 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.19
# 2026-05-03 14:11:50.635 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.35
# 2026-05-03 14:11:50.635 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.16
# 2026-05-03 14:11:50.635 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.16
# 2026-05-03 14:11:50.637 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.32
# 2026-05-03 14:11:50.637 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.13
# 2026-05-03 14:11:50.637 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.13
# 2026-05-03 14:11:50.638 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.29
# 2026-05-03 14:11:50.639 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.10
# 2026-05-03 14:11:50.639 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.10
# 2026-05-03 14:11:50.640 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.26
# 2026-05-03 14:11:50.641 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.07
# 2026-05-03 14:11:50.641 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.07
# 2026-05-03 14:11:50.642 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.23
# 2026-05-03 14:11:50.643 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.04
# 2026-05-03 14:11:50.644 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.04
# 2026-05-03 14:11:50.646 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.20
# 2026-05-03 14:11:50.647 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.01
# 2026-05-03 14:11:50.648 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.01
# 2026-05-03 14:11:50.649 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.17
# 2026-05-03 14:11:50.651 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.651 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.652 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.14
# 2026-05-03 14:11:50.653 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.653 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.655 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.11
# 2026-05-03 14:11:50.655 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.655 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.657 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.08
# 2026-05-03 14:11:50.657 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.657 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.658 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.05
# 2026-05-03 14:11:50.659 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.659 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.660 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.02
# 2026-05-03 14:11:50.661 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.661 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.663 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.663 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.664 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.665 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.666 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.666 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.667 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.668 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.668 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.669 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.670 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.670 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.671 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.672 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.673 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.674 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.675 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.675 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.676 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.676 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.676 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.677 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.678 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# 2026-05-03 14:11:50.678 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# 2026-05-03 14:11:50.679 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# 2026-05-03 14:11:50.680 | INFO     | building_maintenance_agents.house_graph.states.incident_state:update_incident:23 - Update incident: gvs_riser_failure: severity 0.00
# Step 2520:
#   Active incidents: 3
#
# Step 2530:
#   Active incidents: 3
#
# Step 2537:
#   Active incidents: 3
#   Resolved incidents: 2
# 2026-05-03 14:11:50.681 | INFO     | building_maintenance_agents.house_graph.states.incident_state:fix_incident:29 - Fix incident
# Step 2540:
#   Active incidents: 1
#   Resolved incidents: 1
#
# Step 2550:
#   Active incidents: 0
#
# Step 2560:
#   Active incidents: 0
#
# Step 2570:
#   Active incidents: 0
#
# Step 2580:
#   Active incidents: 0
#
# Step 2590:
#   Active incidents: 0
#
# Step 2600:
#   Active incidents: 0
#
# Step 2610:
#   Active incidents: 0
#
# Step 2620:
#   Active incidents: 0
#
# Step 2630:
#   Active incidents: 0
#
# Step 2640:
#   Active incidents: 0
#
# Step 2650:
#   Active incidents: 0
#
# Step 2660:
#   Active incidents: 0
#
# Step 2670:
#   Active incidents: 0
#
# Step 2680:
#   Active incidents: 0
#
# Step 2690:
#   Active incidents: 0
#
# Step 2700:
#   Active incidents: 0
#
# Step 2710:
#   Active incidents: 0
#
# Step 2720:
#   Active incidents: 0
#
# Step 2730:
#   Active incidents: 0
#
# Step 2740:
#   Active incidents: 0
#
# Step 2750:
#   Active incidents: 0
#
# Step 2760:
#   Active incidents: 0
#
# Step 2770:
#   Active incidents: 0
#
# Step 2780:
#   Active incidents: 0
#
# Step 2790:
#   Active incidents: 0
#
# Step 2800:
#   Active incidents: 0
#
# Step 2810:
#   Active incidents: 0
#
# Step 2820:
#   Active incidents: 0
#
# Step 2830:
#   Active incidents: 0
#
# Step 2840:
#   Active incidents: 0
#
# Step 2850:
#   Active incidents: 0
#
# Step 2860:
#   Active incidents: 0
#
# Step 2870:
#   Active incidents: 0
#
# Step 2880:
#   Active incidents: 0
#
# Step 2890:
#   Active incidents: 0
#
# Step 2900:
#   Active incidents: 0
#
# Step 2910:
#   Active incidents: 0
#
# Step 2920:
#   Active incidents: 0
#
# Step 2930:
#   Active incidents: 0
#
# Step 2940:
#   Active incidents: 0
#
# Step 2950:
#   Active incidents: 0
#
# Step 2960:
#   Active incidents: 0
#
# Step 2970:
#   Active incidents: 0
#
# Step 2980:
#   Active incidents: 0
#
# Step 2990:
#   Active incidents: 0

# %% [markdown]
# Statistics:

# %%
stats = simulator.get_statistics()
for key, value in stats.items():
		if key != "incidents_by_type":
				print(f"{key}: {value}")

print("\nIncidents by type:")
for inc_type, count in stats["incidents_by_type"].items():
		print(f"  {inc_type}: {count}")
# Out:
# total_incidents: 2
# max_active_incidents: 3
# total_damage: 1.0716899703680096
# current_time: 3000
# active_incidents: 0
# average_severity: 0.0
#
# Incidents by type:
#   gvs_riser_failure: 2

# %% [markdown]
# In tensors:

# %%
tensors = simulator.get_incident_tensors()
for name, tensor in tensors.items():
		print(f"{name}: shape={tensor.shape}, sum={tensor.sum().item():.2f}")
# Out:
# node_incident: shape=torch.Size([513]), sum=0.00
# node_incident_severity: shape=torch.Size([513]), sum=0.00
# node_incident_type: shape=torch.Size([513, 4]), sum=0.00
# edge_incident: shape=torch.Size([1372]), sum=0.00
# edge_incident_severity: shape=torch.Size([1372]), sum=0.00
# edge_incident_type: shape=torch.Size([1372, 4]), sum=0.00
